# %%
import pickle
import os
import pandas as pd 
import matplotlib.pyplot as plt

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\malachi stoll\anaconda3\lib\site-packages

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000002372DF28A20>

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %%
LOCAL_WOE_ID = 	2514815

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-11-05T17:32:19Z',
#   'created_at': '2017-11-05T17:27:31Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#ShowDosAtrasados',
#     'promoted_content': None,
#     'query': '%23ShowDosAtrasados',
#     'tweet_volume': 630228,
#     'url': 'http://twitter.com/search?q=%23ShowDosAtrasados'},
#    {'name': '#CHEMUN',
#     'promoted_content': None,
#     'query': '%23CHEMUN',
#     'tweet_volume': 59108,
#     'url': 'http://twitter.com/search?q=%23CHEMUN'},
#    {'name': 'Arsenal',
#     'promoted_content': None,
#     'query': 'Arsenal',
#     'tweet_volume': 263526,
#     'url': 'http://twitter.com/search?q=Arsenal'},
#    {'name': '#AbelEnMorfi',
#     'promoted_content': None,
#     'query': '%23AbelEnMorfi',
#     'tweet_volume': 14979,
#     'url': 'http://twitter.com/search?q=%23AbelEnMorfi'},
#    {'name': '#TCSNYCMarathon',
#     'promoted_content': None,
#     'query': '%23TCSNYCMarathon',
#     'tweet_volume': 21734,
#     'url': 'http://twitter.com/search?q=%23TCSNYCMarathon'},
#    {'name': '#OMSMC',
#     'promoted_content': None,
#     'query': '%23OMSMC',
#     'tweet_volume': 15922,
#     'url': 'http://twitter.com/search?q=%23OMSMC'},
#    {'name': 'Shalane Flanagan',
#     'promoted_content': None,
#     'query': '%22Shalane+Flanagan%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Shalane+Flanagan%22'},
#    {'name': 'Lacazette',
#     'promoted_content': None,
#     'query': 'Lacazette',
#     'tweet_volume': 39718,
#     'url': 'http://twitter.com/search?q=Lacazette'},
#    {'name': 'Jack Sock',
#     'promoted_content': None,
#     'query': '%22Jack+Sock%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jack+Sock%22'},
#    {'name': 'Fournette',
#     'promoted_content': None,
#     'query': 'Fournette',
#     'tweet_volume': 11898,
#     'url': 'http://twitter.com/search?q=Fournette'},
#    {'name': 'Flynn',
#     'promoted_content': None,
#     'query': 'Flynn',
#     'tweet_volume': 101770,
#     'url': 'http://twitter.com/search?q=Flynn'},
#    {'name': 'Zach Ertz',
#     'promoted_content': None,
#     'query': '%22Zach+Ertz%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Zach+Ertz%22'},
#    {'name': 'Luiz Gustavo',
#     'promoted_content': None,
#     'query': '%22Luiz+Gustavo%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Luiz+Gustavo%22'},
#    {'name': 'Libras',
#     'promoted_content': None,
#     'query': 'Libras',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Libras'},
#    {'name': '#READYTOPLAY',
#     'promoted_content': None,
#     'query': '%23READYTOPLAY',
#     'tweet_volume': 207407,
#     'url': 'http://twitter.com/search?q=%23READYTOPLAY'},
#    {'name': '#domenicalive',
#     'promoted_content': None,
#     'query': '%23domenicalive',
#     'tweet_volume': 17981,
#     'url': 'http://twitter.com/search?q=%23domenicalive'},
#    {'name': '#STAND_BY_BTS',
#     'promoted_content': None,
#     'query': '%23STAND_BY_BTS',
#     'tweet_volume': 549833,
#     'url': 'http://twitter.com/search?q=%23STAND_BY_BTS'},
#    {'name': '#FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': 35933,
#     'url': 'http://twitter.com/search?q=%23FelizDomingo'},
#    {'name': '#JuveBenevento',
#     'promoted_content': None,
#     'query': '%23JuveBenevento',
#     'tweet_volume': 22560,
#     'url': 'http://twitter.com/search?q=%23JuveBenevento'},
#    {'name': '#مانشستر_سيتي_ارسنال',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1_%D8%B3%D9%8A%D8%AA%D9%8A_%D8%A7%D8%B1%D8%B3%D9%86%D8%A7%D9%84',
#     'tweet_volume': 40937,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1_%D8%B3%D9%8A%D8%AA%D9%8A_%D8%A7%D8%B1%D8%B3%D9%86%D8%A7%D9%84'},
#    {'name': '#تشلسي_يونايتد',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%B4%D9%84%D8%B3%D9%8A_%D9%8A%D9%88%D9%86%D8%A7%D9%8A%D8%AA%D8%AF',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%B4%D9%84%D8%B3%D9%8A_%D9%8A%D9%88%D9%86%D8%A7%D9%8A%D8%AA%D8%AF'},
#    {'name': '#IdolsSA',
#     'promoted_content': None,
#     'query': '%23IdolsSA',
#     'tweet_volume': 20150,
#     'url': 'http://twitter.com/search?q=%23IdolsSA'},
#    {'name': '#enacional',
#     'promoted_content': None,
#     'query': '%23enacional',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23enacional'},
#    {'name': '#SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': 45016,
#     'url': 'http://twitter.com/search?q=%23SundayMorning'},
#    {'name': '#psvtwe',
#     'promoted_content': None,
#     'query': '%23psvtwe',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23psvtwe'},
#    {'name': '#WOBBSC',
#     'promoted_content': None,
#     'query': '%23WOBBSC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23WOBBSC'},
#    {'name': '#FiorentinaRoma',
#     'promoted_content': None,
#     'query': '%23FiorentinaRoma',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FiorentinaRoma'},
#    {'name': '#PREMIERxESPN',
#     'promoted_content': None,
#     'query': '%23PREMIERxESPN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PREMIERxESPN'},
#    {'name': '#DaylightSavingsTime',
#     'promoted_content': None,
#     'query': '%23DaylightSavingsTime',
#     'tweet_volume': 28913,
#     'url': 'http://twitter.com/search?q=%23DaylightSavingsTime'},
#    {'name': '#كمل_يا_بدري',
#     'promoted_content': None,
#     'query': '%23%D9%83%D9%85%D9%84_%D9%8A%D8%A7_%D8%A8%D8%AF%D8%B1%D9%8A',
#     'tweet_volume': 25374,
#     'url': 'http://twitter.com/search?q=%23%D9%83%D9%85%D9%84_%D9%8A%D8%A7_%D8%A8%D8%AF%D8%B1%D9%8A'},
#    {'name': '#الشعب_يحتفل_مع_محمد_بن_سلمان',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B4%D8%B9%D8%A8_%D9%8A%D8%AD%D8%AA%D9%81%D9%84_%D9%85%D8%B9_%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B4%D8%B9%D8%A8_%D9%8A%D8%AD%D8%AA%D9%81%D9%84_%D9%85%D8%B9_%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86'},
#    {'name': '#ThingsWeWillProbablyNeverHear',
#     'promoted_content': None,
#     'query': '%23ThingsWeWillProbablyNeverHear',
#     'tweet_volume': 14254,
#     'url': 'http://twitter.com/search?q=%23ThingsWeWillProbablyNeverHear'},
#    {'name': '#ajautr',
#     'promoted_content': None,
#     'query': '%23ajautr',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ajautr'},
#    {'name': '#GGVGirlWerpa',
#     'promoted_content': None,
#     'query': '%23GGVGirlWerpa',
#     'tweet_volume': 46230,
#     'url': 'http://twitter.com/search?q=%23GGVGirlWerpa'},
#    {'name': '#KOETSG',
#     'promoted_content': None,
#     'query': '%23KOETSG',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23KOETSG'},
#    {'name': '#SeniBuldum',
#     'promoted_content': None,
#     'query': '%23SeniBuldum',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SeniBuldum'},
#    {'name': '#GoVillaricos',
#     'promoted_content': None,
#     'query': '%23GoVillaricos',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23GoVillaricos'},
#    {'name': '#camfilmiyasaklanmasın',
#     'promoted_content': None,
#     'query': '%23camfilmiyasaklanmas%C4%B1n',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23camfilmiyasaklanmas%C4%B1n'},
#    {'name': '#FCMLOSC',
#     'promoted_content': None,
#     'query': '%23FCMLOSC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FCMLOSC'},
#    {'name': '#MHRASM',
#     'promoted_content': None,
#     'query': '%23MHRASM',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MHRASM'},
#    {'name': '#ChievoNapoli',
#     'promoted_content': None,
#     'query': '%23ChievoNapoli',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ChievoNapoli'},
#    {'name': '#CeltaAthletic',
#     'promoted_content': None,
#     'query': '%23CeltaAthletic',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CeltaAthletic'},
#    {'name': '#ظلم_جامعه_حايل',
#     'promoted_content': None,
#     'query': '%23%D8%B8%D9%84%D9%85_%D8%AC%D8%A7%D9%85%D8%B9%D9%87_%D8%AD%D8%A7%D9%8A%D9%84',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%B8%D9%84%D9%85_%D8%AC%D8%A7%D9%85%D8%B9%D9%87_%D8%AD%D8%A7%D9%8A%D9%84'},
#    {'name': '#5Nov',
#     'promoted_content': None,
#     'query': '%235Nov',
#     'tweet_volume': 18301,
#     'url': 'http://twitter.com/search?q=%235Nov'},
#    {'name': '#TEOG',
#     'promoted_content': None,
#     'query': '%23TEOG',
#     'tweet_volume': 59272,
#     'url': 'http://twitter.com/search?q=%23TEOG'},
#    {'name': '#JYPE_TreatGOT7Better',
#     'promoted_content': None,
#     'query': '%23JYPE_TreatGOT7Better',
#     'tweet_volume': 70104,
#     'url': 'http://twitter.com/search?q=%23JYPE_TreatGOT7Better'},
#    {'name': '#A56MesesDeTuSiembraComandante',
#     'promoted_content': None,
#     'query': '%23A56MesesDeTuSiembraComandante',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23A56MesesDeTuSiembraComandante'},
#    {'name': '#66minutes',
#     'promoted_content': None,
#     'query': '%2366minutes',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2366minutes'},
#    {'name': '#OTDirecto5N',
#     'promoted_content': None,
#     'query': '%23OTDirecto5N',
#     'tweet_volume': 22971,
#     'url': 'http://twitter.com/search?q=%23OTDirecto5N'},
#    {'name': '#StressRelievingHobbies',
#     'promoted_content': None,
#     'query': '%23StressRelievingHobbies',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23StressRelievingHobbies'}]}]

# %%
trends = local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#UFC217', 'url': 'http://twitter.com/search?q=%23UFC217', 'promoted_content': None, 'query': '%23UFC217', 'tweet_volume': 384071}, {'name': 'Infinity War', 'url': 'http://twitter.com/search?q=%22Infinity+War%22', 'promoted_content': None, 'query': '%22Infinity+War%22', 'tweet_volume': None}, {'name': 'The Team In Action', 'url': 'http://twitter.com/search?q=%22The+Team+In+Action%22', 'promoted_content': None, 'query': '%22The+Team+In+Action%22', 'tweet_volume': None}, {'name': '#HBOAFM', 'url': 'http://twitter.com/search?q=%23HBOAFM', 'promoted_content': None, 'query': '%23HBOAFM', 'tweet_volume': None}, {'name': '#BeyondCoal', 'url': 'http://twitter.com/search?q=%23BeyondCoal', 'promoted_content': None, 'query': '%23BeyondCoal', 'tweet_volume': None}, {'name': '#TCSNYCMarathon', 'url': 'http://twitter.com/search?q=%23TCSNYCMarathon', 'promoted_content': None, 'query': '%23TCSNYCMarathon', 'tweet_volume': 21734}, {'name': '#SundayMorning', 'url': 'http://twitter.com/search?q=%23SundayMorning', 'promoted_content': None, 'query': '%23SundayMorning', 'tweet_volume': 45016}, {'name': 'Shalane Flanagan', 'url': 'http://twitter.com/search?q=%22Shalane+Flanagan%22', 'promoted_content': None, 'query': '%22Shalane+Flanagan%22', 'tweet_volume': None}, {'name': 'Fournette', 'url': 'http://twitter.com/search?q=Fournette', 'promoted_content': None, 'query': 'Fournette', 'tweet_volume': 11898}, {'name': 'Flynn', 'url': 'http://twitter.com/search?q=Flynn', 'promoted_content': None, 'query': 'Flynn', 'tweet_volume': 101770}, {'name': 'Arsenal', 'url': 'http://twitter.com/search?q=Arsenal', 'promoted_content': None, 'query': 'Arsenal', 'tweet_volume': 263526}, {'name': 'Zach Ertz', 'url': 'http://twitter.com/search?q=%22Zach+Ertz%22', 'promoted_content': None, 'query': '%22Zach+Ertz%22', 'tweet_volume': None}, {'name': 'Tornado Watch', 'url': 'http://twitter.com/search?q=%22Tornado+Watch%22', 'promoted_content': None, 'query': '%22Tornado+Watch%22', 'tweet_volume': None}, {'name': 'Lacazette', 'url': 'http://twitter.com/search?q=Lacazette', 'promoted_content': None, 'query': 'Lacazette', 'tweet_volume': 39718}, {'name': 'Trey Burton', 'url': 'http://twitter.com/search?q=%22Trey+Burton%22', 'promoted_content': None, 'query': '%22Trey+Burton%22', 'tweet_volume': None}, {'name': 'Kellyanne Conway', 'url': 'http://twitter.com/search?q=%22Kellyanne+Conway%22', 'promoted_content': None, 'query': '%22Kellyanne+Conway%22', 'tweet_volume': None}, {'name': '5th of November', 'url': 'http://twitter.com/search?q=%225th+of+November%22', 'promoted_content': None, 'query': '%225th+of+November%22', 'tweet_volume': 19961}, {'name': 'Delanie Walker', 'url': 'http://twitter.com/search?q=%22Delanie+Walker%22', 'promoted_content': None, 'query': '%22Delanie+Walker%22', 'tweet_volume': None}, {'name': 'John Ross', 'url': 'http://twitter.com/search?q=%22John+Ross%22', 'promoted_content': None, 'query': '%22John+Ross%22', 'tweet_volume': None}, {'name': 'Chris Ivory', 'url': 'http://twitter.com/search?q=%22Chris+Ivory%22', 'promoted_content': None, 'query': '%22Chris+Ivory%22', 'tweet_volume': None}, {'name': 'Wenger', 'url': 'http://twitter.com/search?q=Wenger', 'promoted_content': None, 'query': 'Wenger', 'tweet_volume': 45365}, {'name': 'Phil Jones', 'url': 'http://twitter.com/search?q=%22Phil+Jones%22', 'promoted_content': None, 'query': '%22Phil+Jones%22', 'tweet_volume': None}, {'name': 'Raheem Sterling', 'url': 'http://twitter.com/search?q=%22Raheem+Sterling%22', 'promoted_content': None, 'query': '%22Raheem+Sterling%22', 'tweet_volume': None}, {'name': 'Gabriel Jesus', 'url': 'http://twitter.com/search?q=%22Gabriel+Jesus%22', 'promoted_content': None, 'query': '%22Gabriel+Jesus%22', 'tweet_volume': None}, {'name': 'Go to Hell', 'url': 'http://twitter.com/search?q=%22Go+to+Hell%22', 'promoted_content': None, 'query': '%22Go+to+Hell%22', 'tweet_volume': None}, {'name': 'Jack Sock', 'url': 'http://twitter.com/search?q=%22Jack+Sock%22', 'promoted_conte ...

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#TCSNYCMarathon",
#     "url": "http://twitter.com/search?q=%23TCSNYCMarathon",
#     "promoted_content": null,
#     "query": "%23TCSNYCMarathon",
#     "tweet_volume": 21734
#    },
#    {
#     "name": "#SundayMorning",
#     "url": "http://twitter.com/search?q=%23SundayMorning",
#     "promoted_content": null,
#     "query": "%23SundayMorning",
#     "tweet_volume": 45016
#    },
#    {
#     "name": "Shalane Flanagan",
#     "url": "http://twitter.com/search?q=%22Shalane+Flanagan%22",
#     "promoted_content": null,
#     "query": "%22Shalane+Flanagan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DaylightSavingsTime",
#     "url": "http://twitter.com/search?q=%23DaylightSavingsTime",
#     "promoted_content": null,
#     "query": "%23DaylightSavingsTime",
#     "tweet_volume": 28913
#    },
#    {
#     "name": "#ThingsWeWillProbablyNeverHear",
#     "url": "http://twitter.com/search?q=%23ThingsWeWillProbablyNeverHear",
#     "promoted_content": null,
#     "query": "%23ThingsWeWillProbablyNeverHear",
#     "tweet_volume": 14254
#    },
#    {
#     "name": "Fournette",
#     "url": "http://twitter.com/search?q=Fournette",
#     "promoted_content": null,
#     "query": "Fournette",
#     "tweet_volume": 11898
#    },
#    {
#     "name": "Flynn",
#     "url": "http://twitter.com/search?q=Flynn",
#     "promoted_content": null,
#     "query": "Flynn",
#     "tweet_volume": 101770
#    },
#    {
#     "name": "#CHEMUN",
#     "url": "http://twitter.com/search?q=%23CHEMUN",
#     "promoted_content": null,
#     "query": "%23CHEMUN",
#     "tweet_volume": 59108
#    },
#    {
#     "name": "Arsenal",
#     "url": "http://twitter.com/search?q=Arsenal",
#     "promoted_content": null,
#     "query": "Arsenal",
#     "tweet_volume": 263526
#    },
#    {
#     "name": "Zach Ertz",
#     "url": "http://twitter.com/search?q=%22Zach+Ertz%22",
#     "promoted_content": null,
#     "query": "%22Zach+Ertz%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tornado Watch",
#     "url": "http://twitter.com/search?q=%22Tornado+Watch%22",
#     "promoted_content": null,
#     "query": "%22Tornado+Watch%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lacazette",
#     "url": "http://twitter.com/search?q=Lacazette",
#     "promoted_content": null,
#     "query": "Lacazette",
#     "tweet_volume": 39718
#    },
#    {
#     "name": "Trey Burton",
#     "url": "http://twitter.com/search?q=%22Trey+Burton%22",
#     "promoted_content": null,
#     "query": "%22Trey+Burton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kellyanne Conway",
#     "url": "http://twitter.com/search?q=%22Kellyanne+Conway%22",
#     "promoted_content": null,
#     "query": "%22Kellyanne+Conway%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "5th of November",
#     "url": "http://twitter.com/search?q=%225th+of+November%22",
#     "promoted_content": null,
#     "query": "%225th+of+November%22",
#     "tweet_volume": 19961
#    },
#    {
#     "name": "Delanie Walker",
#     "url": "http://twitter.com/search?q=%22Delanie+Walker%22",
#     "promoted_content": null,
#     "query": "%22Delanie+Walker%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "John Ross",
#     "url": "http://twitter.com/search?q=%22John+Ross%22",
#     "promoted_content": null,
#     "query": "%22John+Ross%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chris Ivory",
#     "url": "http://twitter.com/search?q=%22Chris+Ivory%22",
#     "promoted_content": null,
#     "query": "%22Chris+Ivory%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wenger",
#     "url": "http://twitter.com/search?q=Wenger",
#     "promoted_content": null,
#     "query": "Wenger",
#     "tweet_volume": 45365
#    },
#    {
#     "name": "Phil Jones",
#     "url": "http://twitter.com/search?q=%22Phil+Jones%22",
#     "promoted_content": null,
#     "query": "%22Phil+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Raheem Sterling",
#     "url": "http://twitter.com/search?q=%22Raheem+Sterling%22",
#     "promoted_content": null,
#     "query": "%22Raheem+Sterling%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gabriel Jesus",
#     "url": "http://twitter.com/search?q=%22Gabriel+Jesus%22",
#     "promoted_content": null,
#     "query": "%22Gabriel+Jesus%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Go to Hell",
#     "url": "http://twitter.com/search?q=%22Go+to+Hell%22",
#     "promoted_content": null,
#     "query": "%22Go+to+Hell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jack Sock",
#     "url": "http://twitter.com/search?q=%22Jack+Sock%22",
#     "promoted_content": null,
#     "query": "%22Jack+Sock%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Morata",
#     "url": "http://twitter.com/search?q=Morata",
#     "promoted_content": null,
#     "query": "Morata",
#     "tweet_volume": 19669
#    },
#    {
#     "name": "Bakayoko",
#     "url": "http://twitter.com/search?q=Bakayoko",
#     "promoted_content": null,
#     "query": "Bakayoko",
#     "tweet_volume": 16620
#    },
#    {
#     "name": "Chris Jericho",
#     "url": "http://twitter.com/search?q=%22Chris+Jericho%22",
#     "promoted_content": null,
#     "query": "%22Chris+Jericho%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Coquelin",
#     "url": "http://twitter.com/search?q=Coquelin",
#     "promoted_content": null,
#     "query": "Coquelin",
#     "tweet_volume": 15719
#    },
#    {
#     "name": "Hazard",
#     "url": "http://twitter.com/search?q=Hazard",
#     "promoted_content": null,
#     "query": "Hazard",
#     "tweet_volume": 23318
#    },
#    {
#     "name": "#AMJoy",
#     "url": "http://twitter.com/search?q=%23AMJoy",
#     "promoted_content": null,
#     "query": "%23AMJoy",
#     "tweet_volume": 29004
#    },
#    {
#     "name": "#NoirAlley",
#     "url": "http://twitter.com/search?q=%23NoirAlley",
#     "promoted_content": null,
#     "query": "%23NoirAlley",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StressRelievingHobbies",
#     "url": "http://twitter.com/search?q=%23StressRelievingHobbies",
#     "promoted_content": null,
#     "query": "%23StressRelievingHobbies",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DENvsPHI",
#     "url": "http://twitter.com/search?q=%23DENvsPHI",
#     "promoted_content": null,
#     "query": "%23DENvsPHI",
#     "tweet_volume": null
#    },
#    {
#     "name": "#APHA2017",
#     "url": "http://twitter.com/search?q=%23APHA2017",
#     "promoted_content": null,
#     "query": "%23APHA2017",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PrinceRoyceRunsNYC",
#     "url": "http://twitter.com/search?q=%23PrinceRoyceRunsNYC",
#     "promoted_content": null,
#     "query": "%23PrinceRoyceRunsNYC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalDoughnutDay",
#     "url": "http://twitter.com/search?q=%23NationalDoughnutDay",
#     "promoted_content": null,
#     "query": "%23NationalDoughnutDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DontJudgeMeBefore",
#     "url": "http://twitter.com/search?q=%23DontJudgeMeBefore",
#     "promoted_content": null,
#     "query": "%23DontJudgeMeBefore",
#     "tweet_volume": null
#    },
#    {
#     "name": "#tphonline",
#     "url": "http://twitter.com/search?q=%23tphonline",
#     "promoted_content": null,
#     "query": "%23tphonline",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FFNow",
#     "url": "http://twitter.com/search?q=%23FFNow",
#     "promoted_content": null,
#     "query": "%23FFNow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ATLvsCAR",
#     "url": "http://twitter.com/search?q=%23ATLvsCAR",
#     "promoted_content": null,
#     "query": "%23ATLvsCAR",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BoxOffice",
#     "url": "http://twitter.com/search?q=%23BoxOffice",
#     "promoted_content": null,
#     "query": "%23BoxOffice",
#     "tweet_volume": null
#    },
#    {
#     "name": "#brunch",
#     "url": "http://twitter.com/search?q=%23brunch",
#     "promoted_content": null,
#     "query": "%23brunch",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TitanUp",
#     "url": "http://twitter.com/search?q=%23TitanUp",
#     "promoted_content": null,
#     "query": "%23TitanUp",
#     "tweet_volume": null
#    },
#    {
#     "name": "#STAND_BY_BTS",
#     "url": "http://twitter.com/search?q=%23STAND_BY_BTS",
#     "promoted_content": null,
#     "query": "%23STAND_BY_BTS",
#     "tweet_volume": 549833
#    },
#    {
#     "name": "#MTP70",
#     "url": "http://twitter.com/search?q=%23MTP70",
#     "promoted_content": null,
#     "query": "%23MTP70",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheQuestionIAskMyselfMost",
#     "url": "http://twitter.com/search?q=%23TheQuestionIAskMyselfMost",
#     "promoted_content": null,
#     "query": "%23TheQuestionIAskMyselfMost",
#     "tweet_volume": 11461
#    },
#    {
#     "name": "#TBvsNO",
#     "url": "http://twitter.com/search?q=%23TBvsNO",
#     "promoted_content": null,
#     "query": "%23TBvsNO",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-11-05T17:32:19Z",
#   "created_at": "2017-11-05T17:27:31Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
trends_set = {}
trends_set['world'] = set([trend['name']
                          for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name']
                       for trend in us_trends[0]['trends']])

trends_set['DC'] = set([trend['name']
                             for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us', 'DC']:
    print(('-'*10, loc))
    print(('-'.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #JYPE_TreatGOT7Better-#MHRASM-#تشلسي_يونايتد-#enacional-#الشعب_يحتفل_مع_محمد_بن_سلمان-Lacazette-#JuveBenevento-#KOETSG-#STAND_BY_BTS-#ThingsWeWillProbablyNeverHear-Arsenal-Zach Ertz-#GGVGirlWerpa-#ظلم_جامعه_حايل-Jack Sock-Luiz Gustavo-#SeniBuldum-#domenicalive-#CeltaAthletic-#A56MesesDeTuSiembraComandante-Shalane Flanagan-#PREMIERxESPN-#psvtwe-#StressRelievingHobbies-#READYTOPLAY-#IdolsSA-#OMSMC-#ChievoNapoli-#FiorentinaRoma-#FelizDomingo-#SundayMorning-#GoVillaricos-#مانشستر_سيتي_ارسنال-#ShowDosAtrasados-#FCMLOSC-#AbelEnMorfi-#ajautr-Fournette-Flynn-#camfilmiyasaklanmasın-#5Nov-#WOBBSC-#66minutes-#CHEMUN-#OTDirecto5N-#كمل_يا_بدري-Libras-#TEOG-#TCSNYCMarathon-#DaylightSavingsTime
# ('----------', 'us')
# #DENvsPHI-Lacazette-Delanie Walker-#STAND_BY_BTS-Gabriel Jesus-#ThingsWeWillProbablyNeverHear-#DaylightSavingsTime-Arsenal-Zach Ertz-#NoirAlley-#ATLvsCAR-Bakayoko-#tphonline-#TitanUp-Jack Sock-#TBvsNO-#NationalDoughnutDay-Kellyanne Conway-Shalane Flanagan-Phil Jones-#StressRelievingHobbies-Go to Hell-#DontJudgeMeBefore-Coquelin-#SundayMorning-John Ross-Morata-#BoxOffice-#MTP70-Wenger-#brunch-#APHA2017-Hazard-Fournette-#PrinceRoyceRunsNYC-Raheem Sterling-Trey Burton-Chris Ivory-Flynn-Chris Jericho-#CHEMUN-#TheQuestionIAskMyselfMost-#AMJoy-Tornado Watch-#TCSNYCMarathon-5th of November-#FFNow
# ('----------', 'DC')
# #DENvsPHI-Lacazette-Delanie Walker-#STAND_BY_BTS-Gabriel Jesus-#DaylightSavingsTime-Arsenal-Zach Ertz-#NoirAlley-#ATLvsCAR-Bakayoko-#UFC217-#HBOAFM-#tphonline-#TitanUp-Jack Sock-#TBvsNO-#NationalDoughnutDay-Kellyanne Conway-Shalane Flanagan-Phil Jones-#StressRelievingHobbies-Go to Hell-#DontJudgeMeBefore-Coquelin-#SundayMorning-John Ross-Morata-#BoxOffice-#MTP70-Wenger-#brunch-#APHA2017-Hazard-Fournette-#PrinceRoyceRunsNYC-Raheem Sterling-Trey Burton-#BeyondCoal-Chris Ivory-Flynn-The Team In Action-Infinity War-#CHEMUN-#TheQuestionIAskMyselfMost-#AMJoy-Tornado Watch-#TCSNYCMarathon-5th of November-#FFNow

# %%
print(( '='*10, 'intersection of the world and the US'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and DC'))
print((trends_set['DC'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of the world and the US')
# {'Flynn', '#TCSNYCMarathon', '#SundayMorning', 'Jack Sock', 'Lacazette', '#CHEMUN', 'Shalane Flanagan', '#STAND_BY_BTS', '#ThingsWeWillProbablyNeverHear', 'Fournette', 'Arsenal', 'Zach Ertz', '#StressRelievingHobbies', '#DaylightSavingsTime'}
# ('==========', 'intersection of us and DC')
# {'#DENvsPHI', 'Lacazette', 'Delanie Walker', '#STAND_BY_BTS', 'Gabriel Jesus', 'Arsenal', 'Zach Ertz', '#NoirAlley', '#ATLvsCAR', 'Bakayoko', '#TCSNYCMarathon', '#tphonline', '#TitanUp', 'Jack Sock', '#TBvsNO', '#NationalDoughnutDay', 'Kellyanne Conway', 'Shalane Flanagan', '5th of November', 'Phil Jones', '#StressRelievingHobbies', 'Go to Hell', '#DontJudgeMeBefore', 'Coquelin', '#SundayMorning', 'John Ross', 'Morata', '#BoxOffice', '#MTP70', 'Wenger', '#brunch', '#APHA2017', 'Hazard', 'Fournette', 'Raheem Sterling', 'Trey Burton', 'Chris Ivory', 'Flynn', '#CHEMUN', '#TheQuestionIAskMyselfMost', '#AMJoy', 'Tornado Watch', '#PrinceRoyceRunsNYC', '#DaylightSavingsTime', '#FFNow'}

# %%
print(('='*10,'intersection of us and DC'))
print((trends_set['DC'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of us and DC')
# {'#DENvsPHI', 'Lacazette', 'Delanie Walker', '#STAND_BY_BTS', 'Gabriel Jesus', 'Arsenal', 'Zach Ertz', '#NoirAlley', '#ATLvsCAR', 'Bakayoko', '#TCSNYCMarathon', '#tphonline', '#TitanUp', 'Jack Sock', '#TBvsNO', '#NationalDoughnutDay', 'Kellyanne Conway', 'Shalane Flanagan', '5th of November', 'Phil Jones', '#StressRelievingHobbies', 'Go to Hell', '#DontJudgeMeBefore', 'Coquelin', '#SundayMorning', 'John Ross', 'Morata', '#BoxOffice', '#MTP70', 'Wenger', '#brunch', '#APHA2017', 'Hazard', 'Fournette', 'Raheem Sterling', 'Trey Burton', 'Chris Ivory', 'Flynn', '#CHEMUN', '#TheQuestionIAskMyselfMost', '#AMJoy', 'Tornado Watch', '#PrinceRoyceRunsNYC', '#DaylightSavingsTime', '#FFNow'}

# %%
topic = '#trump'

number = 50

search_results = twitter_api.search.tweets(q=topic, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sun Nov 05 17:46:23 +0000 2017', 'id': 927230629024059392, 'id_str': '927230629024059392', 'text': "RT @gmfus: A preview of #Trump's Asia trip agenda: trade, North Korea, and the East Asia Summit https://t.co/QTpD9JTJW7 https://t.co/w5uK5d…", 'truncated': False, 'entities': {'hashtags': [{'text': 'Trump', 'indices': [24, 30]}], 'symbols': [], 'user_mentions': [{'screen_name': 'gmfus', 'name': 'German Marshall Fund', 'id': 33683331, 'id_str': '33683331', 'indices': [3, 9]}], 'urls': [{'url': 'https://t.co/QTpD9JTJW7', 'expanded_url': 'http://bit.ly/2zdefLG', 'display_url': 'bit.ly/2zdefLG', 'indices': [96, 119]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2796534100, 'id_str': '2796534100', 'name': 'Dominic Hopkins', 'screen_name': 'DomHHop', 'location': '', 'description': 'How can I serve you ? Views are my own. RT promote debate.', 'url': 'https://t.co/TQNkyFArRa', 'entities': {'url': {'urls': [{'url': 'https://t.co/TQNkyFArRa', 'expanded_url': 'https://gladstonethemouser.wordpress.com/', 'display_url': 'gladstonethemouser.wordpress.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 483, 'friends_count': 2769, 'listed_count': 52, 'created_at': 'Tue Sep 30 21:54:24 +0000 2014', 'favourites_count': 3809, 'utc_offset': 0, 'time_zone': 'London', 'geo_enabled': True, 'verified': False, 'statuses_count': 16195, 'lang': 'en-gb', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/592009935992528896/JbHK7QJI_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/592009935992528896/JbHK7QJI_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2796534100/1426430266', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Nov 05 14:00:07 +0000 2017', 'id': 927173685806620673, 'id_str': '927173685806620673', 'text': "A preview of #Trump's Asia trip agenda: trade, North Korea, and the East Asia Summit https://t.co/QTpD9JTJW7 https://t.co/w5uK5dfIpv", 'truncated': False, 'entities': {'hashtags': [{'text': 'Trump', 'indices': [13, 19]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QTpD9JTJW7', 'expanded_url': 'http://bit.ly/2zdefLG', 'display_url': 'bit.ly/2zdefLG', 'indices': [85, 108]}], 'media': [{'id': 927173683029741568, 'id_str': '927173683029741568', 'indices': [109, 132], 'media_url': 'http://pbs.twimg.com/media/DN37jWYUEAANcMT.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DN37jWYUEAANcMT.jpg', 'url': 'https://t.co/w5uK5dfIpv', 'display_url': 'pic.twitter.com/w5uK5dfIpv', 'expanded_url': 'https://twitter.com/gmfus/status/927173685806620673/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 780, 'h': 439, 'resize': 'fit'}, 'medium': {'w': 780, 'h': 439, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 927173683029741568, 'id_str': '9271736830 ...

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 44

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["RT @gmfus: A preview of #Trump's Asia trip agenda: trade, North Korea, and the East Asia Summit https://t.co/QTpD9JTJW7 https://t.co/w5uK5d…",
#  'This is AMAZINGLY DISTURBING! #Dotard #Trump #Resist https://t.co/2eCOggCzUA',
#  'RT @dawnresist: #TheResistance\nThe rest of the world is finally catching up!\nAbout damn time!! #MAGAts will do less damage\nthan #Trump &amp; CO…',
#  '@jessphoenix2018 @InSpiteOfTrump @funder Right on! #DonaldTrump has neither a good nor bad #memory. #Trump has a #ConvenientMemory.',
#  '#NewYorkTimes says #King_Fights_Corruption is #Trump’s conspiracy 😱 https://t.co/SDq7NUmIWa',
#  "BULLSHIT REPUBLICAN TAX PLAN LOWERS CORPORATE TAX RATE TO 20% BUT  DOESN'T CLOSE ANY LOOPHOLES FOR THEM    #trumptaxscam #Trump #MAGA",
#  'RT @VeroPArtist: #trump used middle class/ rural vote with promises to #DrainTheSwamp \n\nAll he wanted was to join The Swamp petro dollar le…',
#  'RT @XNSNews: Please Vote &amp; RETWEET: Do you believe #Trump should move Jeff Sessions to a new role and appt someone like Trey Gowdy to Attor…',
#  'RT @RTenfrancais: Une première #rencontre en marge du G20 \n#Trump #Poutine #diplomatie\nhttps://t.co/KF0zlDoP7P',
#  'RT @mswara: Today demonstration in #Tillerson front of Iranian embassy in London #Trump https://t.co/O4oPIET9hy',
#  'RT @Trumpfan1995: What would do if CNN was the only channel available on your TV? Do vote and retweet. #MAGA #Trump',
#  'RT @jjostergaard: i wonder how difficult being a member of #Trump ‘s #DigitalMarketing team? silence while #Mueller is loading..',
#  'Somehow the #FakeNews media will spin this to "Trump Ignoring Hurricane Nate Victims"\n\nThe dishonesty never stops with them. #Trump',
#  'RT @kwilli1046: In 11 Days, there will be a "Come to Jesus" Meeting between #Trump &amp; #Sessions. He Must Enforce the Rule of Law &amp; #LockHerU…',
#  'RT @amjoyshow: .@MAXBOOT: Were there any #Trump senior campaign officials who did not have ties to Russia, and who did not lie about those…',
#  'RT @amjoyshow: .@NAYYEROAR: Knowing that he is going to meet with Putin and Duterte… This is going to embolden #Trump when he comes back to…',
#  "RT @NorthKorea_Newz: #Trump says he's 'open' to meeting with N. Korean leader https://t.co/LTGSVDq7Zm https://t.co/ZkeBkT47Mv",
#  'RT @amjoyshow: .@MAXBOOT: Were there any #Trump senior campaign officials who did not have ties to Russia, and who did not lie about those…',
#  'RT @Unpersuaded112: #trump administration killing silica rule that protects workers from cancer-causing dust #NOT #MAGA https://t.co/YH68cQ…',
#  'RT @Ohio_trade87: USA iPhone Smartwatch https://t.co/3OzXWyuOcT #Trump #POTUS #FLOTUS #NorthKorea #worldwar3 #WorldWarIII #OSU #University…',
#  'RT @efoulon1: La nuit passée, à Bethleem, un artiste courageux peint un baiser entre #Trump &amp; Netanyahu complices de ces murs qui emprisonn…',
#  'Fine Art protesting materials! https://t.co/UL0DPKaJjf #Impeach #Trump #TrumpRussa #TrumpRussia',
#  'RT @MericaSavin: #Trump https://t.co/Cx0QuMPsu2',
#  'RT @rafshmatko: #Trump, #MakeAmericaGreatAgain" – exclusive #wallpapers for #smartphones #HTC #Samsung #LG #Sony #Motorola #phones https://…',
#  'RT @DonnaWR8: IMMIGRATION DIVERSITY LOTTERY🎰\n\n🎥@SebGorka “This is the equivalent of immigration Russian roulette."\n\n#MAGA #TRUMP https://t.…',
#  '#trump the dictator is about to  ruin our existance in the world. Thankyou #usa sheeple you live in a dictatorship',
#  'RT @XNSNews: Please Vote &amp; RETWEET: Do you believe #Trump should move Jeff Sessions to a new role and appt someone like Trey Gowdy to Attor…',
#  '@tmurphy740 @ProudResister He have to Remove His Biatch 1st #Trump',
#  'RT @rafshmatko: #MakeAmericaGreatAgain - Exclusive #background images, #desktop #wallpapers for your #PC, #laptop #Trump https://t.co/NzLC4…',
#  '#Trump #Bitcoin #UFC217 #Bedlam Ohio State #FixMyLife #GuruNanakJayanti Simon Saran Says ‘Teen Mom’ Producers “Brib https://t.co/l7HBKKyFdt',
#  'RT @DearAuntCrabby: THIS is frightening knowing that Republicans are just hunky dory with keeping #Trump in Office even knowing he broke th…',
#  '#Trump #Bitcoin #UFC217 #Bedlam Ohio State #FixMyLife #GuruNanakJayanti Simon Saran Says ‘Teen Mom’ Producers “Brib https://t.co/ddA699uA4N',
#  'RT @kwilli1046: In 11 Days, there will be a "Come to Jesus" Meeting between #Trump &amp; #Sessions. He Must Enforce the Rule of Law &amp; #LockHerU…',
#  'RT @dawnresist: #TheResistance\nThe rest of the world is finally catching up!\nAbout damn time!! #MAGAts will do less damage\nthan #Trump &amp; CO…',
#  'RT @rafshmatko: Nikolai #Shmatko: "His tenure will be successful and his governing reliable" #Trump #DonaldTrump https://t.co/Cqm0fzvpE5 ht…',
#  'if its true...damm #Trump why did u say that?? 😂😂😂 smh \nhttps://t.co/sVQsb9azae',
#  'Obamacare Downward Spiral\nLike America Itself\n#DestructionByDesign\nTraitorous #Trump \nPlanned Failure\nhttps://t.co/muRGoDwEYC\n#SundayMorning',
#  'RT @tizzywoman: SB 1741 would disallow #tRump from unilaterally firing #mueller. @SenMajLdr, what R U afraid of? #complicit #Traitor\nhttps:…',
#  '#maga by paying poverty wages, and hiring overseas workers. Will you "extreme vet" these folks #trump/.… https://t.co/X0e7bvaAXD',
#  'RT @Ohio_trade87: USA iPhone Fitness Bracelet https://t.co/2pRrpmQvsw #Trump #POTUS #FLOTUS #NorthKorea #worldwar3 #WorldWarIII #OSU #Unive…',
#  'RT @EJDionne: "In new interview, #Trump openly rages at checks on his authoritarianism."\nImportant piece @ThePlumLineGS\nhttps://t.co/ipI58d…',
#  'RT @rafshmatko: Welcome! #TRUMP2020 #Trump #DonaldTrump https://t.co/lsoOR0IRx7',
#  'RT @tizzywoman: SB 1741 would disallow #tRump from unilaterally firing #mueller. @SenMajLdr, what R U afraid of? #complicit #Traitor\nhttps:…',
#  "it's a coincidence Iran &amp;North Korea's nuclear programs have rapidly expanded after Obama crafted the Iran uranium deal? Sad but true #Trump",
#  'Poll reveals 65 percent of Americans think #Trump hasn’t accomplished much. https://t.co/SE8Eug1UfL via @slate',
#  '#Canadian company at heart of controversy #Trump and his supporters want to resurrect https://t.co/80ntgQ11BH via @nationalpost #Trudeau',
#  "RT @rafshmatko: #Trump is my choice, not #Russia's! #DonaldTrump #TrumpTrain #MAGA #TrumpisMyChoice https://t.co/5bJmTrmUQx",
#  'But #Trump rigged the entire national election right? This is priceless @JoyAnnReid #LiberalLogic https://t.co/ZY1GmLFonL',
#  'RT @dawnresist: #TheResistance\nThe rest of the world is finally catching up!\nAbout damn time!! #MAGAts will do less damage\nthan #Trump &amp; CO…',
#  'RT @HansAlbers6: #Trump #usa DOW auf Höchststand! Wirtschaft brummt! Arbeitslosenzahl niedrig! Steht bestimmt alles im @DerSPIEGEL drin 👇🏼…']

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
from collections import Counter

for item in [words, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#Trump', 35), ('RT', 27), ('to', 13), ('is', 11), ('the', 10), ('of', 8), ('and', 8), ('a', 7), ('&amp;', 5), ('#MAGA', 5)]
#
# [('Trump', 38), ('MAGA', 5), ('DonaldTrump', 4), ('trump', 4), ('POTUS', 2), ('FLOTUS', 2), ('NorthKorea', 2), ('worldwar3', 2), ('WorldWarIII', 2), ('OSU', 2)]
